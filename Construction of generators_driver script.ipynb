# %%
# set input parameters
choice = 1 # choose a mesh from options 0 to 9
choicealgo1 = 3 # choose algo for 1st spanning tree (0=DFS,1=BFS,3=Kruskal)
choicealgo2 = 2 # choose algo for 2nd spanning tree (0=DFS,1=BFS,2=BFS from graph center)
mesh_resolution = 0.4 # values recommended from 0.2 to 0.4, lower values give higher number of triangles (can inrcrease computation time)
optimization_limit = 10 # set maximal length of paths to be optimized in the generators, -1 gives no limit. Any value other than -1 will also
# limit consideration for optimization to paths that differ to the original by length exactly 1
shifting = False # choose whether shifted cycles should be used

import papermill as pm

pm.execute_notebook(
    "Construction of generators.ipynb",
    "output.ipynb",
    kernel_name="python3",
    log_output=False,
    parameters={
        "choice": choice,
        "choicealgo1": choicealgo1,
        "choicealgo2": choicealgo2,
        "mesh_resolution": mesh_resolution,
        "optimization_limit": optimization_limit,
        "shifting": shifting
    }
)
# Out:
# Executing:   0%|          | 0/31 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': '7873cc65-f587-49c3-b33c-83a0bea8ca52',
#    'metadata': {'editable': True,
#     'slideshow': {'slide_type': ''},
#     'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2026-05-31T12:40:01.978298+00:00',
#      'end_time': '2026-05-31T12:40:01.998769+00:00',
#      'duration': 0.020471,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2026-05-31T12:40:01.990097Z',
#      'iopub.execute_input': '2026-05-31T12:40:01.990506Z',
#      'shell.execute_reply': '2026-05-31T12:40:01.995656Z',
#      'iopub.status.idle': '2026-05-31T12:40:01.996885Z'}},
#    'outputs': [],
# ...
